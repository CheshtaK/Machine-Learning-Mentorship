# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
data = pd.read_csv('adult.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-828edf1f5bc1> in <module>
# ----> 1 data = pd.read_csv('adult.csv')
#
# c:\users\kamalpreet kaur\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\users\kamalpreet kaur\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\kamalpreet kaur\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\kamalpreet kaur\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# c:\users\kamalpreet kaur\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'adult.csv' does not exist: b'adult.csv'

# %%
data.head(30)

# %%
data[data == ' ?'] = np.nan

# %%
data.head(30)
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 0    90                 ?   77053       HS-grad              9
# 1    82           Private  132870       HS-grad              9
# 2    66                 ?  186061  Some-college             10
# 3    54           Private  140359       7th-8th              4
# 4    41           Private  264663  Some-college             10
# 5    34           Private  216864       HS-grad              9
# 6    38           Private  150601          10th              6
# 7    74         State-gov   88638     Doctorate             16
# 8    68       Federal-gov  422013       HS-grad              9
# 9    41           Private   70037  Some-college             10
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51                 ?  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# 24   61                 ?  135285       HS-grad              9
# 25   21           Private   34310     Assoc-voc             11
# 26   33           Private  228696       1st-4th              2
# 27   49           Private  122066       5th-6th              3
# 28   37      Self-emp-inc  107164          10th              6
# 29   38           Private  175360          10th              6
#
#         marital.status         occupation    relationship   race     sex  \
# 0              Widowed                  ?   Not-in-family  White  Female
# 1              Widowed    Exec-managerial   Not-in-family  White  Female
# 2              Widowed                  ?       Unmarried  Black  Female
# 3             Divorced  Machine-op-inspct       Unmarried  White  Female
# 4            Separated     Prof-specialty       Own-child  White  Female
# 5             Divorced      Other-service       Unmarried  White  Female
# 6            Separated       Adm-clerical       Unmarried  White    Male
# 7        Never-married     Prof-specialty  Other-relative  White  Female
# 8             Divorced     Prof-specialty   Not-in-family  White  Female
# 9        Never-married       Craft-repair       Unmarried  White    Male
# 10            Divorced     Prof-specialty       Unmarried  Black  Female
# 11       Never-married     Prof-specialty   Not-in-family  White    Male
# 12             Widowed      Other-service   Not-in-family  White  Female
# 13           Separated    Exec-managerial   Not-in-family  White    Male
# 14       Never-married                  ?   Not-in-family  White    Male
# 15            Divorced     Prof-specialty   Not-in-family  White    Male
# 16            Divorced   Transport-moving   Not-in-family  White    Male
# 17            Divorced    Exec-managerial   Not-in-family  White    Male
# 18       Never-married  Handlers-cleaners   Not-in-family  Black    Male
# 19           Separated              Sales   Not-in-family  White    Male
# 20       Never-married    Exec-managerial   Not-in-family  White    Male
# 21           Separated              Sales   Not-in-family  White  Female
# 22            Divorced              Sales       Unmarried  White  Female
# 23  Married-civ-spouse   Transport-moving         Husband  White    Male
# 24  Married-civ-spouse                  ?         Husband  White    Male
# 25  Married-civ-spouse       Craft-repair         Husband  White    Male
# 26  Married-civ-spouse       Craft-repair   Not-in-family  White    Male
# 27  Married-civ-spouse      Other-service         Husband  White    Male
# 28       Never-married   Transport-moving   Not-in-family  White    Male
# 29       Never-married     Prof-specialty   Not-in-family  White    Male
#
#     capital.gain  capital.loss  hours.per.week native.country income
# 0              0          4356              40  United-States  <=50K
# 1              0          4356              18  United-States  <=50K
# 2              0          4356              40  United-States  <=50K
# 3              0          3900              40  United-States  <=50K
# 4              0          3900              40  United-States  <=50K
# 5              0          3770              45  United-States  <=50K
# 6              0          3770              40  United-States  <=50K
# 7              0          3683              20  United-States   >50K
# 8              0          3683              40  United-States  <=50K
# 9              0          3004              60              ?   >50K
# 10             0          3004              35  United-States   >50K
# 11             0          2824              45  United-States   >50K
# 12             0          2824              20  United-States   >50K
# 13             0          2824              55  United-States   >50K
# 14             0          2824              40  United-States   >50K
# 15             0          2824              40  United-States   >50K
# 16             0          2824              76  United-States   >50K
# 17             0          2824              50  United-States   >50K
# 18             0          2824              40              ?   >50K
# 19             0          2824              50  United-States   >50K
# 20             0          2824              40  United-States   >50K
# 21             0          2754              42  United-States  <=50K
# 22             0          2754              25  United-States  <=50K
# 23             0          2603              40  United-States  <=50K
# 24             0          2603              32  United-States  <=50K
# 25             0          2603              40  United-States  <=50K
# 26             0          2603              32         Mexico  <=50K
# 27             0          2603              40         Greece  <=50K
# 28             0          2559              50  United-States   >50K
# 29             0          2559              90  United-States   >50K

# %%
data['capital.gain'] = data['capital.gain'].replace(0,np.nan)

# %%
data['capital.loss'] = data['capital.loss'].replace(0,np.nan)

# %%
#data['native-country'] = data['native-country'].replace('?',np.nan)

# %%
data.head(30)
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 0    90                 ?   77053       HS-grad              9
# 1    82           Private  132870       HS-grad              9
# 2    66                 ?  186061  Some-college             10
# 3    54           Private  140359       7th-8th              4
# 4    41           Private  264663  Some-college             10
# 5    34           Private  216864       HS-grad              9
# 6    38           Private  150601          10th              6
# 7    74         State-gov   88638     Doctorate             16
# 8    68       Federal-gov  422013       HS-grad              9
# 9    41           Private   70037  Some-college             10
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51                 ?  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# 24   61                 ?  135285       HS-grad              9
# 25   21           Private   34310     Assoc-voc             11
# 26   33           Private  228696       1st-4th              2
# 27   49           Private  122066       5th-6th              3
# 28   37      Self-emp-inc  107164          10th              6
# 29   38           Private  175360          10th              6
#
#         marital.status         occupation    relationship   race     sex  \
# 0              Widowed                  ?   Not-in-family  White  Female
# 1              Widowed    Exec-managerial   Not-in-family  White  Female
# 2              Widowed                  ?       Unmarried  Black  Female
# 3             Divorced  Machine-op-inspct       Unmarried  White  Female
# 4            Separated     Prof-specialty       Own-child  White  Female
# 5             Divorced      Other-service       Unmarried  White  Female
# 6            Separated       Adm-clerical       Unmarried  White    Male
# 7        Never-married     Prof-specialty  Other-relative  White  Female
# 8             Divorced     Prof-specialty   Not-in-family  White  Female
# 9        Never-married       Craft-repair       Unmarried  White    Male
# 10            Divorced     Prof-specialty       Unmarried  Black  Female
# 11       Never-married     Prof-specialty   Not-in-family  White    Male
# 12             Widowed      Other-service   Not-in-family  White  Female
# 13           Separated    Exec-managerial   Not-in-family  White    Male
# 14       Never-married                  ?   Not-in-family  White    Male
# 15            Divorced     Prof-specialty   Not-in-family  White    Male
# 16            Divorced   Transport-moving   Not-in-family  White    Male
# 17            Divorced    Exec-managerial   Not-in-family  White    Male
# 18       Never-married  Handlers-cleaners   Not-in-family  Black    Male
# 19           Separated              Sales   Not-in-family  White    Male
# 20       Never-married    Exec-managerial   Not-in-family  White    Male
# 21           Separated              Sales   Not-in-family  White  Female
# 22            Divorced              Sales       Unmarried  White  Female
# 23  Married-civ-spouse   Transport-moving         Husband  White    Male
# 24  Married-civ-spouse                  ?         Husband  White    Male
# 25  Married-civ-spouse       Craft-repair         Husband  White    Male
# 26  Married-civ-spouse       Craft-repair   Not-in-family  White    Male
# 27  Married-civ-spouse      Other-service         Husband  White    Male
# 28       Never-married   Transport-moving   Not-in-family  White    Male
# 29       Never-married     Prof-specialty   Not-in-family  White    Male
#
#     capital.gain  capital.loss  hours.per.week native.country income
# 0            NaN        4356.0              40  United-States  <=50K
# 1            NaN        4356.0              18  United-States  <=50K
# 2            NaN        4356.0              40  United-States  <=50K
# 3            NaN        3900.0              40  United-States  <=50K
# 4            NaN        3900.0              40  United-States  <=50K
# 5            NaN        3770.0              45  United-States  <=50K
# 6            NaN        3770.0              40  United-States  <=50K
# 7            NaN        3683.0              20  United-States   >50K
# 8            NaN        3683.0              40  United-States  <=50K
# 9            NaN        3004.0              60              ?   >50K
# 10           NaN        3004.0              35  United-States   >50K
# 11           NaN        2824.0              45  United-States   >50K
# 12           NaN        2824.0              20  United-States   >50K
# 13           NaN        2824.0              55  United-States   >50K
# 14           NaN        2824.0              40  United-States   >50K
# 15           NaN        2824.0              40  United-States   >50K
# 16           NaN        2824.0              76  United-States   >50K
# 17           NaN        2824.0              50  United-States   >50K
# 18           NaN        2824.0              40              ?   >50K
# 19           NaN        2824.0              50  United-States   >50K
# 20           NaN        2824.0              40  United-States   >50K
# 21           NaN        2754.0              42  United-States  <=50K
# 22           NaN        2754.0              25  United-States  <=50K
# 23           NaN        2603.0              40  United-States  <=50K
# 24           NaN        2603.0              32  United-States  <=50K
# 25           NaN        2603.0              40  United-States  <=50K
# 26           NaN        2603.0              32         Mexico  <=50K
# 27           NaN        2603.0              40         Greece  <=50K
# 28           NaN        2559.0              50  United-States   >50K
# 29           NaN        2559.0              90  United-States   >50K

# %%
mean_value_gain=data['capital.gain'].mean()
data['capital.gain']=data['capital.gain'].fillna(mean_value_gain)

mean_value_loss=data['capital.loss'].mean()
data['capital.loss']=data['capital.loss'].fillna(mean_value_loss)

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female  12938.541298
# 1    Exec-managerial  Not-in-family  White  Female  12938.541298
# 2                  ?      Unmarried  Black  Female  12938.541298
# 3  Machine-op-inspct      Unmarried  White  Female  12938.541298
# 4     Prof-specialty      Own-child  White  Female  12938.541298
#
#    capital.loss  hours.per.week native.country income
# 0        4356.0              40  United-States  <=50K
# 1        4356.0              18  United-States  <=50K
# 2        4356.0              40  United-States  <=50K
# 3        3900.0              40  United-States  <=50K
# 4        3900.0              40  United-States  <=50K

# %%
#data['workclass']=data['workclass'].replace('?',np.NaN, inplace=True)

# %%
#data.head(30)

# %%
#data = data.drop(['marital.status','relationship', 'race','native-country'], axis=1)

# %%
from sklearn import preprocessing

categorical = ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']
for feature in categorical:
        le = preprocessing.LabelEncoder()
        data[feature] = le.fit_transform(data[feature])

# %%
data.head(100)
# Out:
#     age  workclass  fnlwgt  education  education.num  marital.status  \
# 0    90          0   77053         11              9               6
# 1    82          4  132870         11              9               6
# 2    66          0  186061         15             10               6
# 3    54          4  140359          5              4               0
# 4    41          4  264663         15             10               5
# 5    34          4  216864         11              9               0
# 6    38          4  150601          0              6               5
# 7    74          7   88638         10             16               4
# 8    68          1  422013         11              9               0
# 9    41          4   70037         15             10               4
# 10   45          4  172274         10             16               0
# 11   38          6  164526         14             15               4
# 12   52          4  129177          9             13               6
# 13   32          4  136204         12             14               5
# 14   51          0  172175         10             16               4
# 15   46          4   45363         14             15               0
# 16   45          4  172822          1              7               0
# 17   57          4  317847         12             14               0
# 18   22          4  119592          7             12               4
# 19   34          4  203034          9             13               5
# 20   37          4  188774          9             13               4
# 21   29          4   77009          1              7               5
# 22   61          4   29059         11              9               0
# 23   51          4  153870         15             10               2
# 24   61          0  135285         11              9               2
# 25   21          4   34310          8             11               2
# 26   33          4  228696          3              2               2
# 27   49          4  122066          4              3               2
# 28   37          5  107164          0              6               4
# 29   38          4  175360          0              6               4
# ..  ...        ...     ...        ...            ...             ...
# 70   49          4  199029          9             13               2
# 71   47          6  145290         11              9               2
# 72   41          2  297248         14             15               2
# 73   55          5  227856          9             13               2
# 74   39          4  179731         12             14               2
# 75   42          4  154374          9             13               2
# 76   41          0   27187          8             11               2
# 77   46          4  326857         12             14               2
# 78   40          4  160369         12             14               2
# 79   32          4  396745          9             13               2
# 80   41          5  151089         15             10               2
# 81   60          5  336188         14             15               2
# 82   31          4  279015         12             14               2
# 83   58          6   43221         15             10               2
# 84   37          5   30529          9             13               2
# 85   44          6  201742          9             13               2
# 86   39          6  218490         14             15               2
# 87   43          1  156996         14             15               2
# 88   55          5  298449          9             13               2
# 89   44          5  191712         12             14               2
# 90   39          4  198654         14             15               2
# 91   46          6  102308          9             13               2
# 92   39          4  348521         15             10               2
# 93   62          5   56248          9             13               2
# 94   31          6  252752         11              9               2
# 95   46          4  192963          9             13               2
# 96   46          6  198759         14             15               2
# 97   39          5  143123          8             11               2
# 98   39          4  237713         14             15               2
# 99   59          4   81929         10             16               2
#
#     occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0            0             1     4    0  12938.541298        4356.0
# 1            4             1     4    0  12938.541298        4356.0
# 2            0             4     2    0  12938.541298        4356.0
# 3            7             4     4    0  12938.541298        3900.0
# 4           10             3     4    0  12938.541298        3900.0
# 5            8             4     4    0  12938.541298        3770.0
# 6            1             4     4    1  12938.541298        3770.0
# 7           10             2     4    0  12938.541298        3683.0
# 8           10             1     4    0  12938.541298        3683.0
# 9            3             4     4    1  12938.541298        3004.0
# 10          10             4     2    0  12938.541298        3004.0
# 11          10             1     4    1  12938.541298        2824.0
# 12           8             1     4    0  12938.541298        2824.0
# 13           4             1     4    1  12938.541298        2824.0
# 14           0             1     4    1  12938.541298        2824.0
# 15          10             1     4    1  12938.541298        2824.0
# 16          14             1     4    1  12938.541298        2824.0
# 17           4             1     4    1  12938.541298        2824.0
# 18           6             1     2    1  12938.541298        2824.0
# 19          12             1     4    1  12938.541298        2824.0
# 20           4             1     4    1  12938.541298        2824.0
# 21          12             1     4    0  12938.541298        2754.0
# 22          12             4     4    0  12938.541298        2754.0
# 23          14             0     4    1  12938.541298        2603.0
# 24           0             0     4    1  12938.541298        2603.0
# 25           3             0     4    1  12938.541298        2603.0
# 26           3             1     4    1  12938.541298        2603.0
# 27           8             0     4    1  12938.541298        2603.0
# 28          14             1     4    1  12938.541298        2559.0
# 29          10             1     4    1  12938.541298        2559.0
# ..         ...           ...   ...  ...           ...           ...
# 70          12             0     4    1  12938.541298        2415.0
# 71           4             0     4    1  12938.541298        2415.0
# 72          10             0     4    1  12938.541298        2415.0
# 73           4             0     4    1  12938.541298        2415.0
# 74           4             5     4    0  12938.541298        2415.0
# 75           4             0     4    1  12938.541298        2415.0
# 76           0             0     4    1  12938.541298        2415.0
# 77          12             0     4    1  12938.541298        2415.0
# 78           4             0     4    1  12938.541298        2415.0
# 79          10             0     4    1  12938.541298        2415.0
# 80           4             0     4    1  12938.541298        2415.0
# 81          10             0     4    1  12938.541298        2415.0
# 82           4             0     4    1  12938.541298        2415.0
# 83           5             0     4    1  12938.541298        2415.0
# 84          12             0     4    1  12938.541298        2415.0
# 85           4             0     4    1  12938.541298        2415.0
# 86          10             0     4    1  12938.541298        2415.0
# 87          10             0     1    1  12938.541298        2415.0
# 88           4             0     4    1  12938.541298        2415.0
# 89          10             0     4    1  12938.541298        2415.0
# 90          10             0     1    1  12938.541298        2415.0
# 91          12             0     4    1  12938.541298        2415.0
# 92           5             0     4    1  12938.541298        2415.0
# 93           5             0     4    1  12938.541298        2415.0
# 94           8             5     4    0  12938.541298        2415.0
# 95           1             0     1    1  12938.541298        2415.0
# 96          10             0     4    1  12938.541298        2415.0
# 97           3             0     4    1  12938.541298        2415.0
# 98          12             0     4    1  12938.541298        2415.0
# 99          10             0     4    1  12938.541298        2415.0
#
#     hours.per.week  native.country income
# 0               40              39  <=50K
# 1               18              39  <=50K
# 2               40              39  <=50K
# 3               40              39  <=50K
# 4               40              39  <=50K
# 5               45              39  <=50K
# 6               40              39  <=50K
# 7               20              39   >50K
# 8               40              39  <=50K
# 9               60               0   >50K
# 10              35              39   >50K
# 11              45              39   >50K
# 12              20              39   >50K
# 13              55              39   >50K
# 14              40              39   >50K
# 15              40              39   >50K
# 16              76              39   >50K
# 17              50              39   >50K
# 18              40               0   >50K
# 19              50              39   >50K
# 20              40              39   >50K
# 21              42              39  <=50K
# 22              25              39  <=50K
# 23              40              39  <=50K
# 24              32              39  <=50K
# 25              40              39  <=50K
# 26              32              26  <=50K
# 27              40              12  <=50K
# 28              50              39   >50K
# 29              90              39   >50K
# ..             ...             ...    ...
# 70              55              39   >50K
# 71              50              39   >50K
# 72              45              39   >50K
# 73              50              39   >50K
# 74              65              39   >50K
# 75              60              39   >50K
# 76              12              39   >50K
# 77              65              39   >50K
# 78              45              39   >50K
# 79              48              39   >50K
# 80              55              39   >50K
# 81              80              39   >50K
# 82              70              36   >50K
# 83              40              39   >50K
# 84              50              39   >50K
# 85              50              39   >50K
# 86              50               0   >50K
# 87              55               0   >50K
# 88              50              39   >50K
# 89              55              39   >50K
# 90              67              19   >50K
# 91              40              39   >50K
# 92              99              39   >50K
# 93              60              39   >50K
# 94              40              39   >50K
# 95              35              30   >50K
# 96              80              39   >50K
# 97              40              39   >50K
# 98              99              39   >50K
# 99              45              39   >50K
#
# [100 rows x 15 columns]

# %%
X_train= data.drop('income',axis=1)
X_test= data['income']
